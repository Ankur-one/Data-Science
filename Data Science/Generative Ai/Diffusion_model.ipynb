# %%
# !pip install keras-cv
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# WARNING: Ignoring invalid distribution ~umpy (C:\Users\2005a\AppData\Roaming\Python\Python313\site-packages)
# WARNING: Ignoring invalid distribution ~umpy (C:\Users\2005a\AppData\Roaming\Python\Python313\site-packages)
# WARNING: Ignoring invalid distribution ~umpy (C:\Users\2005a\AppData\Roaming\Python\Python313\site-packages)

# %%
import sys
print(sys.version)

# !pip show tensorflow
# !pip show protobuf
# !pip show keras
# !pip show keras-cv
# Out:
# 3.13.9 | packaged by Anaconda, Inc. | (main, Oct 21 2025, 19:09:58) [MSC v.1929 64 bit (AMD64)]
# Name: tensorflow
# Version: 2.21.0
# Summary: TensorFlow is an open source machine learning framework for everyone.
# Home-page: https://www.tensorflow.org/
# Author: Google Inc.
# Author-email: packages@tensorflow.org
# License: Apache 2.0
# Location: C:\Users\2005a\AppData\Roaming\Python\Python313\site-packages
# Requires: absl-py, astunparse, flatbuffers, gast, google_pasta, grpcio, h5py, keras, libclang, ml_dtypes, numpy, opt_einsum, packaging, protobuf, requests, setuptools, six, termcolor, typing_extensions, wrapt
# Required-by:
# WARNING: Ignoring invalid distribution ~umpy (C:\Users\2005a\AppData\Roaming\Python\Python313\site-packages)
# Name: protobuf
# Version: 7.35.1
# Summary:
# Home-page: https://developers.google.com/protocol-buffers/
# Author: protobuf@googlegroups.com
# Author-email: protobuf@googlegroups.com
# License: 3-Clause BSD License
# ...

# %%
# !pip install --upgrade protobuf
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# WARNING: Ignoring invalid distribution ~umpy (C:\Users\2005a\AppData\Roaming\Python\Python313\site-packages)
# WARNING: Ignoring invalid distribution ~umpy (C:\Users\2005a\AppData\Roaming\Python\Python313\site-packages)
# WARNING: Ignoring invalid distribution ~umpy (C:\Users\2005a\AppData\Roaming\Python\Python313\site-packages)

# %%
import sys

# !{sys.executable} -m pip install tensorflow keras keras-cv
# Out:
# ...
# WARNING: Ignoring invalid distribution ~umpy (C:\Users\2005a\AppData\Roaming\Python\Python313\site-packages)
# WARNING: Ignoring invalid distribution ~umpy (C:\Users\2005a\AppData\Roaming\Python\Python313\site-packages)

# %%
import time
import keras_cv
import keras
import matplotlib.pyplot as plt

# %%
model = keras_cv.models.StableDiffusion(
    img_width=512, img_height=512, jit_compile=False
)
# Out:
# By using this model checkpoint, you acknowledge that its usage is subject to the terms of the CreativeML Open RAIL-M license at https://raw.githubusercontent.com/CompVis/stable-diffusion/main/LICENSE

# %%
import shutil

total, used, free = shutil.disk_usage("C:\\")

print(f"Free space: {free / (1024**3):.2f} GB")
# Out:
# Free space: 269.11 GB

# %%
import sys
# !{sys.executable} -m pip cache purge
# Out:
# Files removed: 2 (324 kB)
# Directories removed: 0

# %%
import shutil

_, _, free = shutil.disk_usage("C:\\")
print(f"Free space: {free / (1024**3):.2f} GB")
# Out:
# Free space: 269.11 GB

# %%
import keras_cv
import matplotlib.pyplot as plt

# Load Stable Diffusion model
model = keras_cv.models.StableDiffusion(
    img_width=512,
    img_height=512
)

# Generate image
images = model.text_to_image(
    "A beautiful sunset over the Himalayas",
    batch_size=1
)

# Display image
plt.imshow(images[0])
plt.axis("off")
plt.show()
# Out:
# By using this model checkpoint, you acknowledge that its usage is subject to the terms of the CreativeML Open RAIL-M license at https://raw.githubusercontent.com/CompVis/stable-diffusion/main/LICENSE
# WARNING:tensorflow:From C:\Users\2005a\AppData\Roaming\Python\Python313\site-packages\keras\src\backend\tensorflow\core.py:232: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1696s 32s/step
# ...
# 198180272/198180272 ━━━━━━━━━━━━━━━━━━━━ 213s 1us/step
