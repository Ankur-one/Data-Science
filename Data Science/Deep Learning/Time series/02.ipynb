# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
df = pd.read_csv('Airline-passengers.csv')
df.head()
# Out:
#      Month  Passengers
# 0  1949-01         112
# 1  1949-02         118
# 2  1949-03         132
# 3  1949-04         129
# 4  1949-05         121

# %% [markdown]
# # data preprocessing

# %%
# Change the names columns
df.columns = ['Date', 'Number of Passengers']
df.head()
# Out:
#       Date  Number of Passengers
# 0  1949-01                   112
# 1  1949-02                   118
# 2  1949-03                   132
# 3  1949-04                   129
# 4  1949-05                   121

# %%
# PLot the data
sns.set(rc={'figure.figsize': (15,5)})
sns.lineplot(x='Date', y='Number of Passengers', data=df)
# Out:
# <Axes: xlabel='Date', ylabel='Number of Passengers'>

# %%
import plotly.express as px
fig = px.line(df, x='Date', y='Number of Passengers', title='Number of passenger over time')
fig.show()

# %%
# Make a sided plot using matplotlib
fig, ax = plt.subplots(figsize=(15,5))
ax.plot(df['Date'], df['Number of Passengers'], color='red')
ax.set_xlabel('Date', fontsize=14)
ax.set_ylabel('Number of Passengers', color='red', fontsize=14)
ax.set_title('Number of Passengers over time', fontsize=14)
ax.tick_params(axis='y', color='red', labelsize=14)
ax.tick_params(axis='x', labelsize=6, rotation=90)
ax2 = ax.twinx()
ax2.plot(df['Date'], df['Number of Passengers'], color='blue')
ax2.set_xlabel('Date', fontsize=14)
ax2.set_ylabel('Number of Passengers', color='blue', fontsize=14)
ax2.set_title('Number of Passengers over time', fontsize=14)
ax2.tick_params(axis='y', color='blue', labelsize=14)
ax2.tick_params(axis='x', labelsize=6, rotation=90)
plt.show()
