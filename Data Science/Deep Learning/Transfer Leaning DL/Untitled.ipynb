# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import tensorflow as tf
#ignore warnings

import warnings
warnings.filterwarnings("ignore")

# %%
# !pip install tensorflow-datasets
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: tensorflow-datasets in c:\users\2005a\appdata\roaming\python\python313\site-packages (4.9.10)
# Requirement already satisfied: absl-py in c:\users\2005a\appdata\roaming\python\python313\site-packages (from tensorflow-datasets) (2.4.0)
# Requirement already satisfied: dm-tree in c:\users\2005a\appdata\roaming\python\python313\site-packages (from tensorflow-datasets) (0.1.10)
# Requirement already satisfied: etils>=1.9.1 in c:\users\2005a\appdata\roaming\python\python313\site-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets) (1.14.0)
# Requirement already satisfied: immutabledict in c:\users\2005a\appdata\roaming\python\python313\site-packages (from tensorflow-datasets) (4.3.1)
# Requirement already satisfied: numpy in c:\users\2005a\appdata\roaming\python\python313\site-packages (from tensorflow-datasets) (2.4.3)
# Requirement already satisfied: promise in c:\users\2005a\appdata\roaming\python\python313\site-packages (from tensorflow-datasets) (2.3)
# Requirement already satisfied: protobuf>=3.20 in c:\users\2005a\appdata\roaming\python\python313\site-packages (from tensorflow-datasets) (6.33.4)
# Requirement already satisfied: psutil in c:\users\2005a\appdata\roaming\python\python313\site-packages (from tensorflow-datasets) (7.2.2)
# Requirement already satisfied: pyarrow in c:\users\2005a\appdata\roaming\python\python313\site-packages (from tensorflow-datasets) (22.0.0)
# Requirement already satisfied: requests>=2.19.0 in c:\users\2005a\appdata\roaming\python\python313\site-packages (from tensorflow-datasets) (2.32.5)
# Requirement already satisfied: simple_parsing in c:\users\2005a\appdata\roaming\python\python313\site-packages (from tensorflow-datasets) (0.1.8)
# Requirement already satisfied: tensorflow-metadata in c:\users\2005a\appdata\roaming\python\python313\site-packages (from tensorflow-datasets) (1.21.0)
# Requirement already satisfied: termcolor in c:\users\2005a\appdata\roaming\python\python313\site-packages (from tensorflow-datasets) (3.3.0)
# Requirement already satisfied: toml in c:\users\2005a\appdata\roaming\python\python313\site-packages (from tensorflow-datasets) (0.10.2)
# Requirement already satisfied: tqdm in c:\users\2005a\appdata\roaming\python\python313\site-packages (from tensorflow-datasets) (4.67.3)
# Requirement already satisfied: wrapt in c:\users\2005a\appdata\roaming\python\python313\site-packages (from tensorflow-datasets) (2.1.2)
# Requirement already satisfied: einops in c:\users\2005a\appdata\roaming\python\python313\site-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets) (0.8.2)
# Requirement already satisfied: fsspec in c:\users\2005a\appdata\roaming\python\python313\site-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets) (2026.6.0)
# Requirement already satisfied: typing_extensions in c:\users\2005a\appdata\roaming\python\python313\site-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets) (4.15.0)
# Requirement already satisfied: zipp in c:\users\2005a\appdata\roaming\python\python313\site-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets) (4.1.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\2005a\appdata\roaming\python\python313\site-packages (from requests>=2.19.0->tensorflow-datasets) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\2005a\appdata\roaming\python\python313\site-packages (from requests>=2.19.0->tensorflow-datasets) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\2005a\appdata\roaming\python\python313\site-packages (from requests>=2.19.0->tensorflow-datasets) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\2005a\appdata\roaming\python\python313\site-packages (from requests>=2.19.0->tensorflow-datasets) (2026.6.17)
# Requirement already satisfied: attrs>=18.2.0 in c:\users\2005a\appdata\roaming\python\python313\site-packages (from dm-tree->tensorflow-datasets) (25.4.0)
# Requirement already satisfied: six in c:\users\2005a\appdata\roaming\python\python313\site-packages (from promise->tensorflow-datasets) (1.17.0)
# Requirement already satisfied: docstring-parser~=0.15 in c:\users\2005a\appdata\roaming\python\python313\site-packages (from simple_parsing->tensorflow-datasets) (0.18.0)
# Requirement already satisfied: googleapis-common-protos<2,>=1.56.4 in c:\users\2005a\appdata\roaming\python\python313\site-packages (from tensorflow-metadata->tensorflow-datasets) (1.75.0)
# Requirement already satisfied: colorama in c:\users\2005a\appdata\roaming\python\python313\site-packages (from tqdm->tensorflow-datasets) (0.4.6)
# WARNING: Ignoring invalid distribution ~umpy (C:\Users\2005a\AppData\Roaming\Python\Python313\site-packages)
# WARNING: Ignoring invalid distribution ~umpy (C:\Users\2005a\AppData\Roaming\Python\Python313\site-packages)
# WARNING: Ignoring invalid distribution ~umpy (C:\Users\2005a\AppData\Roaming\Python\Python313\site-packages)
#
# [notice] A new release of pip is available: 25.3 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os

# Base folder
base_dir = "cats_vs_dogs"

# Folder paths
folders = [
    os.path.join(base_dir, "train", "cats"),
    os.path.join(base_dir, "train", "dogs"),
    os.path.join(base_dir, "validation", "cats"),
    os.path.join(base_dir, "validation", "dogs"),
    os.path.join(base_dir, "test", "cats"),
    os.path.join(base_dir, "test", "dogs")
]

# Create folders
for folder in folders:
    os.makedirs(folder, exist_ok=True)
    print(f"Created: {folder}")

print("\nAll folders created successfully!")
# Out:
# Created: cats_vs_dogs\train\cats
# Created: cats_vs_dogs\train\dogs
# Created: cats_vs_dogs\validation\cats
# Created: cats_vs_dogs\validation\dogs
# Created: cats_vs_dogs\test\cats
# Created: cats_vs_dogs\test\dogs
#
# All folders created successfully!

# %%
import tensorflow as tf
import tensorflow_datasets as tfds

(train_ds, test_ds), ds_info = tfds.load(
    'cats_vs_dogs',
    split=['train[:80%]', 'train[80%:]'],
    as_supervised=True,
    with_info=True
)

print(ds_info)
BATCH_SIZE = 32
IMG_SIZE = (160, 160)

train_dataset = tf.keras.utils.image_dataset_from_directory(train_dir,
                                                            shuffle=True,
                                                            batch_size=BATCH_SIZE,
                                                            image_size=IMG_SIZE)
# Out:
# WARNING:absl:Variant folder C:\Users\2005a\tensorflow_datasets\cats_vs_dogs\4.0.1 has no dataset_info.json
# Downloading and preparing dataset Unknown size (download: Unknown size, generated: Unknown size, total: Unknown size) to C:\Users\2005a\tensorflow_datasets\cats_vs_dogs\4.0.1...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Generating splits...:   0%|          | 0/1 [00:00<?, ? splits/s]
# Generating train examples...: 0 examples [00:00, ? examples/s]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 4
#       1 import tensorflow as tf
#       2 import tensorflow_datasets as tfds
# ----> 4 (train_ds, test_ds), ds_info = tfds.load(
#       5     'cats_vs_dogs',
#       6     split=['train[:80%]', 'train[80%:]'],
#       7     as_supervised=True,
#       8     with_info=True
#       9 )
#      11 print(ds_info)
#      12 BATCH_SIZE = 32
#
# File ~\AppData\Roaming\Python\Python313\site-packages\tensorflow_datasets\core\logging\__init__.py:176, in _FunctionDecorator.__call__(self, function, instance, args, kwargs)
#     174 metadata = self._start_call()
#     175 try:
# --> 176   return function(*args, **kwargs)
#     177 except Exception:
#     178   metadata.mark_error()
#
# File ~\AppData\Roaming\Python\Python313\site-packages\tensorflow_datasets\core\load.py:669, in load(name, split, data_dir, batch_size, shuffle_files, download, as_supervised, decoders, read_config, with_info, builder_kwargs, download_and_prepare_kwargs, as_dataset_kwargs, try_gcs, file_format)
#     662 with ctx:
#     663   dbuilder = _fetch_builder(
#     664       name=name,
#     665       data_dir=data_dir,
#     666       builder_kwargs=builder_kwargs,
#     667       try_gcs=try_gcs,
#     668   )
# --> 669 _download_and_prepare_builder(dbuilder, download, download_and_prepare_kwargs)
#     671 if as_dataset_kwargs is None:
#     672   as_dataset_kwargs = {}
#
# File ~\AppData\Roaming\Python\Python313\site-packages\tensorflow_datasets\core\load.py:519, in _download_and_prepare_builder(dbuilder, download, download_and_prepare_kwargs)
#     517 if download:
#     518   download_and_prepare_kwargs = download_and_prepare_kwargs or {}
# --> 519   dbuilder.download_and_prepare(**download_and_prepare_kwargs)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\tensorflow_datasets\core\logging\__init__.py:176, in _FunctionDecorator.__call__(self, function, instance, args, kwargs)
#     174 metadata = self._start_call()
#     175 try:
# --> 176   return function(*args, **kwargs)
#     177 except Exception:
#     178   metadata.mark_error()
#
# File ~\AppData\Roaming\Python\Python313\site-packages\tensorflow_datasets\core\dataset_builder.py:770, in DatasetBuilder.download_and_prepare(self, download_dir, download_config, file_format, permissions)
#     768   self.info.read_from_directory(self.data_dir)
#     769 else:
# --> 770   self._download_and_prepare(
#     771       dl_manager=dl_manager,
#     772       download_config=download_config,
#     773   )
#     775   # NOTE: If modifying the lines below to put additional information in
#     776   # DatasetInfo, you'll likely also want to update
#     777   # DatasetInfo.read_from_directory to possibly restore these attributes
#     778   # when reading from package data.
#     779   self.info.download_size = dl_manager.downloaded_size
#
# File ~\AppData\Roaming\Python\Python313\site-packages\tensorflow_datasets\core\dataset_builder.py:1819, in GeneratorBasedBuilder._download_and_prepare(self, dl_manager, download_config)
#    1816 if download_config.max_examples_per_split == 0:
#    1817   return
# -> 1819 split_infos = self._generate_splits(dl_manager, download_config)
#    1821 # Update the info object with the splits.
#    1822 split_dict = splits_lib.SplitDict(split_infos)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\tensorflow_datasets\core\dataset_builder.py:1793, in GeneratorBasedBuilder._generate_splits(self, dl_manager, download_config)
#    1786   for split_name, generator in utils.tqdm(
#    1787       split_generators.items(),
#    1788       desc="Generating splits...",
#    1789       unit=" splits",
#    1790       leave=False,
#    1791   ):
#    1792     filename_template = self._get_filename_template(split_name=split_name)
# -> 1793     future = split_builder.submit_split_generation(
#    1794         split_name=split_name,
#    1795         generator=generator,
#    1796         filename_template=filename_template,
#    1797         disable_shuffling=self.info.disable_shuffling,
#    1798         nondeterministic_order=download_config.nondeterministic_order,
#    1799     )
#    1800     split_info_futures.append(future)
#    1802 # Process the result of the beam pipeline.
#
# File ~\AppData\Roaming\Python\Python313\site-packages\tensorflow_datasets\core\split_builder.py:448, in SplitBuilder.submit_split_generation(self, split_name, generator, filename_template, disable_shuffling, nondeterministic_order)
#     443     logging.warning(
#     444         '`nondeterministic_order` is set to True for a dataset that does'
#     445         ' not use beam. Setting `disable_shuffling` to True.'
#     446     )
#     447     build_kwargs['disable_shuffling'] = True
# --> 448   return self._build_from_generator(**build_kwargs)
#     449 else:  # Otherwise, beam required
#     450   unknown_generator_type = TypeError(
#     451       f'Invalid split generator value for split `{split_name}`. '
#     452       'Expected generator or apache_beam object. Got: '
#     453       f'{type(generator)}'
#     454   )
#
# File ~\AppData\Roaming\Python\Python313\site-packages\tensorflow_datasets\core\split_builder.py:509, in SplitBuilder._build_from_generator(self, split_name, generator, filename_template, disable_shuffling)
#     499 serialized_info = self._features.get_serialized_info()
#     500 writer = writer_lib.Writer(
#     501     serializer=example_serializer.ExampleSerializer(serialized_info),
#     502     filename_template=filename_template,
#    (...)
#     507     ignore_duplicates=self._ignore_duplicates,
#     508 )
# --> 509 for i, (key, example) in enumerate(
#     510     utils.tqdm(
#     511         generator,
#     512         desc=f'Generating {split_name} examples...',
#     513         unit=' examples',
#     514         total=total_num_examples,
#     515         leave=False,
#     516         mininterval=1.0,
#     517     )
#     518 ):
#     519   try:
#     520     example = self._features.encode_example(example)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\tqdm\notebook.py:250, in tqdm_notebook.__iter__(self)
#     248 try:
#     249     it = super().__iter__()
# --> 250     yield from it
#     251 # NB: except ... [ as ...] breaks IPython async KeyboardInterrupt
#     252 except:  # NOQA
#
# File ~\AppData\Roaming\Python\Python313\site-packages\tqdm\std.py:1181, in tqdm.__iter__(self)
#    1178 time = self._time
#    1180 try:
# -> 1181     for obj in iterable:
#    1182         yield obj
#    1183         # Update and possibly print the progressbar.
#    1184         # Note: does not call self.update(1) for speed optimisation.
#
# File ~\AppData\Roaming\Python\Python313\site-packages\tensorflow_datasets\image_classification\cats_vs_dogs.py:119, in CatsVsDogs._generate_examples(self, archive)
#     117 with zipfile.ZipFile(buffer, "w") as new_zip:
#     118   new_zip.writestr(norm_fname, img_recoded.numpy())
# --> 119 new_fobj = zipfile.ZipFile(buffer).open(norm_fname)
#     121 record = {
#     122     "image": new_fobj,
#     123     "image/filename": norm_fname,
#     124     "label": label,
#     125 }
#     126 yield norm_fname, record
#
# File D:\anaconda3\Lib\zipfile\__init__.py:1639, in ZipFile.open(self, name, mode, pwd, force_zip64)
#    1636     zinfo.compress_level = self.compresslevel
#    1637 else:
#    1638     # Get info object for name
# -> 1639     zinfo = self.getinfo(name)
#    1641 if mode == 'w':
#    1642     return self._open_to_write(zinfo, force_zip64=force_zip64)
#
# File D:\anaconda3\Lib\zipfile\__init__.py:1567, in ZipFile.getinfo(self, name)
#    1565 info = self.NameToInfo.get(name)
#    1566 if info is None:
# -> 1567     raise KeyError(
#    1568         'There is no item named %r in the archive' % name)
#    1570 return info
#
# KeyError: "There is no item named 'PetImages\\\\Cat\\\\0.jpg' in the archive"

# %%
validation_dataset = tf.keras.utils.image_dataset_from_directory(validation_dir,
                                                                 shuffle=True,
                                                                 batch_size=BATCH_SIZE,
                                                                 image_size=IMG_SIZE)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 validation_dataset = tf.keras.utils.image_dataset_from_directory(validation_dir,
#       2                                                                  shuffle=True,
#       3                                                                  batch_size=BATCH_SIZE,
#       4                                                                  image_size=IMG_SIZE)
#
# NameError: name 'validation_dir' is not defined

# %%
class_names = train_dataset.class_names

plt.figure(figsize=(10, 10))
for images, labels in train_dataset.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 class_names = train_dataset.class_names
#       3 plt.figure(figsize=(10, 10))
#       4 for images, labels in train_dataset.take(1):
#
# NameError: name 'train_dataset' is not defined

# %%
val_batches = tf.data.experimental.cardinality(validation_dataset)
test_dataset = validation_dataset.take(val_batches // 5)
validation_dataset = validation_dataset.skip(val_batches // 5)
print('Number of validation batches: %d' % tf.data.experimental.cardinality(validation_dataset))
print('Number of test batches: %d' % tf.data.experimental.cardinality(test_dataset))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 val_batches = tf.data.experimental.cardinality(validation_dataset)
#       2 test_dataset = validation_dataset.take(val_batches // 5)
#       3 validation_dataset = validation_dataset.skip(val_batches // 5)
#
# NameError: name 'validation_dataset' is not defined

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_dataset = train_dataset.prefetch(buffer_size=AUTOTUNE)
validation_dataset = validation_dataset.prefetch(buffer_size=AUTOTUNE)
test_dataset = test_dataset.prefetch(buffer_size=AUTOTUNE)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 3
#       1 AUTOTUNE = tf.data.AUTOTUNE
# ----> 3 train_dataset = train_dataset.prefetch(buffer_size=AUTOTUNE)
#       4 validation_dataset = validation_dataset.prefetch(buffer_size=AUTOTUNE)
#       5 test_dataset = test_dataset.prefetch(buffer_size=AUTOTUNE)
#
# NameError: name 'train_dataset' is not defined

# %%
data_augmentation = tf.keras.Sequential([
  tf.keras.layers.RandomFlip('horizontal'),
  tf.keras.layers.RandomRotation(0.2),
])

# %%
for image, _ in train_dataset.take(1):
  plt.figure(figsize=(10, 10))
  first_image = image[0]
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    augmented_image = data_augmentation(tf.expand_dims(first_image, 0))
    plt.imshow(augmented_image[0] / 255)
    plt.axis('off')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 for image, _ in train_dataset.take(1):
#       2   plt.figure(figsize=(10, 10))
#       3   first_image = image[0]
#
# NameError: name 'train_dataset' is not defined

# %%
preprocess_input = tf.keras.applications.mobilenet_v2.preprocess_input
rescale = tf.keras.layers.Rescaling(1./127.5, offset=-1)
# Create the base model from the pre-trained model MobileNet V2
IMG_SHAPE = IMG_SIZE + (3,)
base_model = tf.keras.applications.MobileNetV2(input_shape=IMG_SHAPE,
                                               include_top=False,
                                               weights='imagenet')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 4
#       2 rescale = tf.keras.layers.Rescaling(1./127.5, offset=-1)
#       3 # Create the base model from the pre-trained model MobileNet V2
# ----> 4 IMG_SHAPE = IMG_SIZE + (3,)
#       5 base_model = tf.keras.applications.MobileNetV2(input_shape=IMG_SHAPE,
#       6                                                include_top=False,
#       7                                                weights='imagenet')
#
# NameError: name 'IMG_SIZE' is not defined

# %%
image_batch, label_batch = next(iter(train_dataset))
feature_batch = base_model(image_batch)
print(feature_batch.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 image_batch, label_batch = next(iter(train_dataset))
#       2 feature_batch = base_model(image_batch)
#       3 print(feature_batch.shape)
#
# NameError: name 'train_dataset' is not defined

# %%
base_model.trainable = False
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 base_model.trainable = False
#
# NameError: name 'base_model' is not defined

# %%
# Let's take a look at the base model architecture
base_model.summary()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 2
#       1 # Let's take a look at the base model architecture
# ----> 2 base_model.summary()
#
# NameError: name 'base_model' is not defined

# %%
len(model.trainable_variables)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 len(model.trainable_variables)
#
# NameError: name 'model' is not defined

# %%
# for window/linux users
base_learning_rate = 0.0001
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=base_learning_rate),
              loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),
              metrics=[tf.keras.metrics.BinaryAccuracy(threshold=0, name='accuracy')])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 3
#       1 # for window/linux users
#       2 base_learning_rate = 0.0001
# ----> 3 model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=base_learning_rate),
#       4               loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),
#       5               metrics=[tf.keras.metrics.BinaryAccuracy(threshold=0, name='accuracy')])
#
# NameError: name 'model' is not defined

# %%
# %%time
initial_epochs = 10

loss0, accuracy0 = model.evaluate(validation_dataset)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File <timed exec>:3
#
# NameError: name 'model' is not defined

# %%
print("initial loss: {:.2f}".format(loss0))
print("initial accuracy: {:.2f}".format(accuracy0))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 print("initial loss: {:.2f}".format(loss0))
#       2 print("initial accuracy: {:.2f}".format(accuracy0))
#
# NameError: name 'loss0' is not defined

# %%
history = model.fit(train_dataset,
                    epochs=initial_epochs,
                    validation_data=validation_dataset, verbose=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 history = model.fit(train_dataset,
#       2                     epochs=initial_epochs,
#       3                     validation_data=validation_dataset, verbose=1)
#
# NameError: name 'model' is not defined

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.ylim([0,1.0])
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 acc = history.history['accuracy']
#       2 val_acc = history.history['val_accuracy']
#       4 loss = history.history['loss']
#
# NameError: name 'history' is not defined
