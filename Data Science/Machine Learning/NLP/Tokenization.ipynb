# %%
# !pip install nltk
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached nltk-3.10.3-py3-none-any.whl.metadata (3.2 kB)
# ...
# Using cached nltk-3.10.3-py3-none-any.whl (1.8 MB)
# ...
# WARNING: Ignoring invalid distribution ~umpy (C:\Users\2005a\AppData\Roaming\Python\Python313\site-packages)
# WARNING: Ignoring invalid distribution ~umpy (C:\Users\2005a\AppData\Roaming\Python\Python313\site-packages)
#   WARNING: The script nltk.exe is installed in 'C:\Users\2005a\AppData\Roaming\Python\Python313\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# WARNING: Ignoring invalid distribution ~umpy (C:\Users\2005a\AppData\Roaming\Python\Python313\site-packages)
#
# [notice] A new release of pip is available: 26.1.2 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import nltk

nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\2005a\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
## Tokenization
fcorpus = "Hello, my name is Ankur. I am learning NLP. NLP is very interesting."

sentences = sent_tokenize(corpus)

print(sentences)
# Out:
# ["Hello Welcome, to Ankur'NLP class.", 'Please do watch the entire course to become expert in NLP']

# %%
type(sentences)
# Out:
# list

# %% [markdown]
# ## Paragraph--->words
# ## Sentences ---> words

# %%
from nltk.tokenize import word_tokenize
sentence = "NLP is a branch of Artificial Intelligence."

words = word_tokenize(sentence)

print(words)
# Out:
# ['NLP', 'is', 'a', 'branch', 'of', 'Artificial', 'Intelligence', '.']

# %%
import nltk

nltk.download('punkt_tab')

from nltk.tokenize import sent_tokenize, word_tokenize

paragraph = """
NLP is a branch of Artificial Intelligence.
It helps computers understand human language.
Tokenization is an important step in NLP.
"""

# Paragraph → Sentences
sentences = sent_tokenize(paragraph)

print("Sentences:")
print(sentences)

# Sentences → Words
print("\nWords:")

for sentence in sentences:
    words = word_tokenize(sentence)
    print(words)
# Out:
# Sentences:
# ['\nNLP is a branch of Artificial Intelligence.', 'It helps computers understand human language.', 'Tokenization is an important step in NLP.']
#
# Words:
# ['NLP', 'is', 'a', 'branch', 'of', 'Artificial', 'Intelligence', '.']
# ['It', 'helps', 'computers', 'understand', 'human', 'language', '.']
# ['Tokenization', 'is', 'an', 'important', 'step', 'in', 'NLP', '.']
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\2005a\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
